# %%
import tensorflow as tf
import re, json, pickle
from tqdm import tqdm
import numpy as np
import pathlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pre_path = '/content/drive/MyDrive/Special_Topic/Dataset'
anno_path = pre_path + '/MSCOCO_2017/2017_annotations/captions_train2017.json'
glove_path = pre_path + '/MSCOCO_2017/GloVe.6B/glove.6B.300d.txt'
p_path = pre_path + '/FasterRCNNDataset'

# %%
input_file = open(anno_path)
annotation = json.load(input_file)

# %%
image_id = 32664

# %%
caption = ' a herd of cattle standing under a leafy green tree <end>'
for x in tqdm(annotation['annotations']):
      if x['image_id'] == image_id:
      # if x['caption'][3:20] == caption[4:20]:
        # print(caption[3:20])
        print(x)
        # break
# Out:
# 100%|██████████| 591753/591753 [00:00<00:00, 2516840.14it/s]
# {'image_id': 32664, 'id': 225198, 'caption': 'A bench made out of two poles and a blue surfboard.'}
# {'image_id': 32664, 'id': 255087, 'caption': 'A bench made of a surfboard near a pier complex.'}
# {'image_id': 32664, 'id': 255489, 'caption': 'BLUE BENCH RESEMBLING A SURF BOARD NEAR THE PIER'}
# {'image_id': 32664, 'id': 256653, 'caption': 'A beach side bench is painted to resemble a surfboard. '}
# {'image_id': 32664, 'id': 263448, 'caption': 'A surfing board is sitting outside of the water on its holder. '}

# %% [markdown]
# http://images.cocodataset.org/train2017/000000191381.jpg
# http://images.cocodataset.org/train2017/000000218439.jpg
#
# http://images.cocodataset.org/train2017/000000000283.jpg
